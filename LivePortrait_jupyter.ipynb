# %% [markdown]
# <a href="https://colab.research.google.com/github/pantakanVor/Test_By_Pantakan/blob/main/LivePortrait_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/LivePortrait
# %cd /content/LivePortrait

# !rm -rf /content/LivePortrait/pretrained_weights
# !git clone https://huggingface.co/camenduru/LivePortrait /content/LivePortrait/pretrained_weights

# !pip install tyro==0.8.5 onnxruntime-gpu==1.18.1 onnx==1.16.1 gradio==4.36.1 colorama

# %cd /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython
# !python setup.py build_ext --inplace
# Out:
# /content
# Cloning into 'LivePortrait'...
# remote: Enumerating objects: 334, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 334 (delta 60), reused 60 (delta 60), pack-reused 247 (from 1)
# Receiving objects: 100% (334/334), 27.63 MiB | 35.95 MiB/s, done.
# Resolving deltas: 100% (104/104), done.
# /content/LivePortrait
# Cloning into '/content/LivePortrait/pretrained_weights'...
# remote: Enumerating objects: 19, done.
# remote: Total 19 (delta 0), reused 0 (delta 0), pack-reused 19 (from 1)
# Unpacking objects: 100% (19/19), 3.49 KiB | 713.00 KiB/s, done.
# Filtering content: 100% (8/8), 628.42 MiB | 78.71 MiB/s, done.
# Collecting tyro==0.8.5
#   Downloading tyro-0.8.5-py3-none-any.whl.metadata (8.2 kB)
# Collecting onnxruntime-gpu==1.18.1
#   Downloading onnxruntime_gpu-1.18.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting onnx==1.16.1
#   Downloading onnx-1.16.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting gradio==4.36.1
#   Downloading gradio-4.36.1-py3-none-any.whl.metadata (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.12/dist-packages (from tyro==0.8.5) (0.17.0)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from tyro==0.8.5) (4.15.0)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.12/dist-packages (from tyro==0.8.5) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro==0.8.5)
#   Downloading shtab-1.8.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting coloredlogs (from onnxruntime-gpu==1.18.1)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (25.12.19)
# Collecting numpy<2.0,>=1.21.6 (from onnxruntime-gpu==1.18.1)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (1.14.0)
# Collecting aiofiles<24.0,>=22.0 (from gradio==4.36.1)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (5.5.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.123.10)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (1.0.0)
# Collecting gradio-client==1.0.1 (from gradio==4.36.1)
#   Downloading gradio_client-1.0.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.36.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (3.1.6)
# Collecting markupsafe~=2.0 (from gradio==4.36.1)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (3.10.0)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (3.11.5)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (2.2.2)
# Collecting pillow<11.0,>=8.0 (from gradio==4.36.1)
#   Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.0.21)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (6.0.3)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.14.11)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (2.10.0)
# Collecting tomlkit==0.12.0 (from gradio==4.36.1)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.21.1)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (2.5.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.40.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.0.1->gradio==4.36.1) (2025.3.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==1.0.1->gradio==4.36.1)
#   Downloading websockets-11.0.3-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==4.36.1) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==4.36.1) (2.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.36.1) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (3.20.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==4.36.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==4.36.1) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->gradio==4.36.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->gradio==4.36.1) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->gradio==4.36.1) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro==0.8.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro==0.8.5) (2.19.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==4.36.1) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==4.36.1) (1.5.4)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu==1.18.1)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->gradio==4.36.1) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi->gradio==4.36.1) (0.0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu==1.18.1) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro==0.8.5) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.36.1) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.19.3->gradio==4.36.1) (3.4.4)
# Downloading tyro-0.8.5-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 6.9 MB/s eta 0:00:00
# Downloading onnxruntime_gpu-1.18.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (200.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.8/200.8 MB 5.5 MB/s eta 0:00:00
# Downloading onnx-1.16.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 88.3 MB/s eta 0:00:00
# Downloading gradio-4.36.1-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 95.6 MB/s eta 0:00:00
# Downloading gradio_client-1.0.1-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.1/318.1 kB 19.2 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 82.2 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 114.9 MB/s eta 0:00:00
# Downloading shtab-1.8.0-py3-none-any.whl (14 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.8 MB/s eta 0:00:00
# Downloading websockets-11.0.3-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: websockets, tomlkit, shtab, pillow, numpy, markupsafe, humanfriendly, colorama, aiofiles, onnx, coloredlogs, tyro, onnxruntime-gpu, gradio-client, gradio
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.13.3
#     Uninstalling tomlkit-0.13.3:
#       Successfully uninstalled tomlkit-0.13.3
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 24.1.0
#     Uninstalling aiofiles-24.1.0:
#       Successfully uninstalled aiofiles-24.1.0
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.14.0
#     Uninstalling gradio_client-1.14.0:
#       Successfully uninstalled gradio_client-1.14.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 5.50.0
#     Uninstalling gradio-5.50.0:
#       Successfully uninstalled gradio-5.50.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.36.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.21.0 requires websockets<16.0.0,>=15.0.1, but you have websockets 11.0.3 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# google-genai 1.55.0 requires websockets<15.1.0,>=13.0.0, but you have websockets 11.0.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 11.0.3 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# dataproc-spark-connect 1.0.1 requires websockets>=14.0, but you have websockets 11.0.3 which is incompatible.
# Successfully installed aiofiles-23.2.1 colorama-0.4.6 coloredlogs-15.0.1 gradio-4.36.1 gradio-client-1.0.1 humanfriendly-10.0 markupsafe-2.1.5 numpy-1.26.4 onnx-1.16.1 onnxruntime-gpu-1.18.1 pillow-10.4.0 shtab-1.8.0 tomlkit-0.12.0 tyro-0.8.5 websockets-11.0.3
# /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython
# Compiling mesh_core_cython.pyx because it changed.
# [1/1] Cythonizing mesh_core_cython.pyx
# /usr/local/lib/python3.12/dist-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython/mesh_core_cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# In file included from /usr/local/lib/python3.12/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /usr/local/lib/python3.12/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.12/dist-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from mesh_core_cython.cpp:1264:
# /usr/local/lib/python3.12/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~

# %%
# !dmesg | tail -n 20
# Out:
# [   24.755366] LoadPin: firmware pinning-excluded obj="/var/lib/nvidia/firmware/nvidia/550.54.15/gsp_tu10x.bin" pid=1485 cmdline="/var/lib/nvidia/bin/nvidia-persistenced --verbose"
# [   24.777740] nvidia 0000:00:04.0: loading /var/lib/nvidia/firmware/nvidia/550.54.15/gsp_tu10x.bin failed with error -13
# [   24.789795] nvidia 0000:00:04.0: Direct firmware load for nvidia/550.54.15/gsp_tu10x.bin failed with error -2
# [   25.299171] LoadPin: kernel-module pinning-excluded obj="/lib/modules/6.6.105+/kernel/net/netfilter/xt_nat.ko" pid=1503 cmdline="/sbin/modprobe -q -- ipt_DNAT"
# [   25.825292] LoadPin: kernel-module pinning-excluded obj="/lib/modules/6.6.105+/kernel/drivers/net/veth.ko" pid=1605 cmdline="/sbin/modprobe -q -- rtnl-link-veth"
# [   25.850198] docker0: port 1(veth8641b9c) entered blocking state
# [   25.856284] docker0: port 1(veth8641b9c) entered disabled state
# [   25.862360] veth8641b9c: entered allmulticast mode
# [   25.867376] veth8641b9c: entered promiscuous mode
# [   26.107885] eth0: renamed from veth9b00e7b
# [   26.117821] docker0: port 1(veth8641b9c) entered blocking state
# [   26.124359] docker0: port 1(veth8641b9c) entered forwarding state
# [   26.914860] br0: port 1(veth84f13b3) entered blocking state
# [   26.920588] br0: port 1(veth84f13b3) entered disabled state
# [   26.926310] veth84f13b3: entered allmulticast mode
# [   26.931290] veth84f13b3: entered promiscuous mode
# [   27.427351] eth0: renamed from vethc73abb6
# [   27.434210] br0: port 1(veth84f13b3) entered blocking state
# [   27.439927] br0: port 1(veth84f13b3) entered forwarding state
# [ 3655.526304] printk: dmesg (201827): Attempt to access syslog with CAP_SYS_ADMIN but no CAP_SYSLOG (deprecated).

# %%
# %cd /content/LivePortrait

# ตรวจสอบว่ามี GPU จริงไหม (ต้องขึ้นว่า True)
import torch
print(f"GPU Available: {torch.cuda.is_available()}")

# รันประมวลผล
# !python inference.py \
    -s assets/examples/source/s0.jpg \
    -d assets/examples/driving/d0.mp4 \
    --output-dir results/final_success \
    --no-flag-do-crop \
    --flag-relative
# Out:
# /content/LivePortrait
# GPU Available: False
# Traceback (most recent call last):
#   File "/content/LivePortrait/inference.py", line 33, in <module>
#     main()
#   File "/content/LivePortrait/inference.py", line 23, in main
#     live_portrait_pipeline = LivePortraitPipeline(
#                              ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/LivePortrait/src/live_portrait_pipeline.py", line 38, in __init__
#     self.live_portrait_wrapper: LivePortraitWrapper = LivePortraitWrapper(cfg=inference_cfg)
#                                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/LivePortrait/src/live_portrait_wrapper.py", line 29, in __init__
#     self.appearance_feature_extractor = load_model(cfg.checkpoint_F, model_config, cfg.device_id, 'appearance_feature_extractor')
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/LivePortrait/src/utils/helper.py", line 99, in load_model
#     model = AppearanceFeatureExtractor(**model_params).cuda(device)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1084, in cuda
#     return self._apply(lambda t: t.cuda(device))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 930, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 930, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 957, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1084, in <lambda>
#     return self._apply(lambda t: t.cuda(device))
#                                  ^^^^^^^^^^^^^^
# RuntimeError: Cannot access accelerator device when none is available.

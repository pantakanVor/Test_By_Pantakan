# %% [markdown]
# <a href="https://colab.research.google.com/github/pantakanVor/Test_By_Pantakan/blob/main/LivePortrait_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML
from base64 import b64encode

# Path where the file was just saved
video_path = '/content/lizard_final_test.mp4'

# Open and encode the video
mp4 = open(video_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# Display the player
HTML(f"""
<video width="600" controls>
      <source src="{data_url}" type="video/mp4">
</video>
""")
# Out:
# <video width="600" controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
import torch
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
# %cd /content/Wav2Lip
# !python inference.py \
    --checkpoint_path checkpoints/wav2lip_gan.pth \
    --face "/content/LivePortrait/assets/examples/source/lizard2.jpg" \
    --audio "/content/LivePortrait/assets/examples/driving/script.mp3" \
    --outfile "/content/lizard_final_test.mp4" \
    --static True \
    --box 100 450 100 450 \
    --pads 0 20 0 0
# Out:
# GPU available: True
# Device Name: Tesla T4
# /content/Wav2Lip
# Using cuda for inference.
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Models loaded
# Number of frames available for inference: 1
# Extracting raw audio...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x5aa2fcb19480] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/content/LivePortrait/assets/examples/driving/script.mp3':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Duration: 00:01:04.60, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'temp/temp.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    5564kB time=00:01:04.57 bitrate= 705.9kbits/s speed= 547x
# video:0kB audio:5564kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001369%
# (80, 5169)
# Length of mel chunks: 1612
#   0% 0/13 [00:00<?, ?it/s]Using the specified bounding box instead of face detection...
# 100% 13/13 [00:15<00:00,  1.17s/it]
# wav2lip prediction time: 15.275838136672974
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from 'temp/result.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:01:04.48, start: 0.000000, bitrate: 1903 kb/s
#   Stream #0:0: Video: mpeg4 (Simple Profile) (DIVX / 0x58564944), yuv420p, 1024x1024 [SAR 1:1 DAR 1:1], 1898 kb/s, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from 'temp/temp.wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:01:04.60, bitrate: 705 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5d3700c97240] using SAR=1/1
# [libx264 @ 0x5d3700c97240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5d3700c97240] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5d3700c97240] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/lizard_final_test.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1024x1024 [SAR 1:1 DAR 1:1], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac

# %%
import torch
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
# %cd /content/Wav2Lip
# !python inference.py \
    --checkpoint_path checkpoints/wav2lip_gan.pth \
    --face "/content/LivePortrait/assets/examples/source/lizard.png" \
    --audio "/content/LivePortrait/assets/examples/driving/script.mp3" \
    --outfile "/content/lizard_final_test.mp4" \
    --static True \
    --box 100 450 100 450 \
    --pads 0 20 0 0
# Out:
# GPU available: True
# Device Name: Tesla T4
# /content/Wav2Lip
# Using cuda for inference.
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Models loaded
# Number of frames available for inference: 1
# Extracting raw audio...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x58bc48389480] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/content/LivePortrait/assets/examples/driving/script.mp3':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Duration: 00:01:04.60, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'temp/temp.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    5564kB time=00:01:04.57 bitrate= 705.9kbits/s speed= 459x
# video:0kB audio:5564kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001369%
# (80, 5169)
# Length of mel chunks: 1612
#   0% 0/13 [00:00<?, ?it/s]Using the specified bounding box instead of face detection...
# 100% 13/13 [00:12<00:00,  1.01it/s]
# wav2lip prediction time: 12.850074529647827
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from 'temp/result.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:01:04.48, start: 0.000000, bitrate: 1708 kb/s
#   Stream #0:0: Video: mpeg4 (Simple Profile) (DIVX / 0x58564944), yuv420p, 682x1024 [SAR 1:1 DAR 341:512], 1704 kb/s, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from 'temp/temp.wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:01:04.60, bitrate: 705 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5b2750efb400] using SAR=1/1
# [libx264 @ 0x5b2750efb400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5b2750efb400] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5b2750efb400] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/lizard_final_test.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 682x1024 [SAR 1:1 DAR 341:512], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame= 1612 fps= 58 q=-1.0 Lsize=    2393kB time=00:01:04.59 bitrate= 303.5kbits/s speed=2.31x
# video:1792kB audio:548kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.275874%
# [libx264 @ 0x5b2750efb400] frame I:7     Avg QP:15.54  size: 94830
# [libx264 @ 0x5b2750efb400] frame P:609   Avg QP:19.22  size:  1320
# [libx264 @ 0x5b2750efb400] frame B:996   Avg QP:26.29  size:   368
# [libx264 @ 0x5b2750efb400] consecutive B-frames: 14.4%  7.9%  5.2% 72.5%
# [libx264 @ 0x5b2750efb400] mb I  I16..4:  9.0% 84.0%  7.0%
# [libx264 @ 0x5b2750efb400] mb P  I16..4:  0.1%  0.7%  0.0%  P16..4:  5.9%  1.8%  0.9%  0.0%  0.0%    skip:90.6%
# [libx264 @ 0x5b2750efb400] mb B  I16..4:  0.0%  0.2%  0.0%  B16..8:  4.8%  0.3%  0.0%  direct: 0.1%  skip:94.5%  L0:51.4% L1:45.7% BI: 2.9%
# [libx264 @ 0x5b2750efb400] 8x8 transform intra:84.2% inter:91.7%
# [libx264 @ 0x5b2750efb400] coded y,uvDC,uvAC intra: 69.6% 58.6% 14.6% inter: 1.5% 1.2% 0.0%
# [libx264 @ 0x5b2750efb400] i16 v,h,dc,p: 40% 16% 17% 27%
# [libx264 @ 0x5b2750efb400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 18% 31%  3%  3%  4%  4%  5%  5%
# [libx264 @ 0x5b2750efb400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 20% 11%  4%  6%  6%  4%  6%  4%
# [libx264 @ 0x5b2750efb400] i8c dc,h,v,p: 46% 25% 25%  5%
# [libx264 @ 0x5b2750efb400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5b2750efb400] ref P L0: 60.1% 12.1% 17.5% 10.4%
# [libx264 @ 0x5b2750efb400] ref B L0: 79.5% 13.6%  6.9%
# [libx264 @ 0x5b2750efb400] ref B L1: 95.9%  4.1%
# [libx264 @ 0x5b2750efb400] kb/s:227.55
# [aac @ 0x5b2750efd080] Qavg: 137.185

# %%
import torch
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
# %cd /content/Wav2Lip

# !python inference.py \
    --checkpoint_path checkpoints/wav2lip_gan.pth \
    --face "/content/LivePortrait/assets/examples/source/lizard2.jpg" \
    --audio "/content/LivePortrait/assets/examples/driving/script.mp3" \
    --outfile "/content/lizard_force.mp4"
# Out:
# GPU available: True
# Device Name: Tesla T4
# /content/Wav2Lip
# Using cuda for inference.
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Models loaded
# Number of frames available for inference: 1
# Extracting raw audio...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x5709a7709480] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/content/LivePortrait/assets/examples/driving/script.mp3':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Duration: 00:01:04.60, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'temp/temp.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    5564kB time=00:01:04.57 bitrate= 705.9kbits/s speed= 532x
# video:0kB audio:5564kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001369%
# (80, 5169)
# Length of mel chunks: 1612
#   0% 0/13 [00:03<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/Wav2Lip/inference.py", line 327, in <module>
#     main()
#   File "/content/Wav2Lip/inference.py", line 254, in main
#     for i, (img_batch, mel_batch, frames, coords) in enumerate(tqdm(gen,
#                                                      ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/content/Wav2Lip/inference.py", line 106, in datagen
#     face_det_results = face_detect([frames[0]])
#                        ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Wav2Lip/inference.py", line 81, in face_detect
#     raise ValueError('Face not detected! Ensure the video contains a face in all the frames.')
# ValueError: Face not detected! Ensure the video contains a face in all the frames.

# %%
import torch
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
# %cd /content/Wav2Lip
# !python inference.py \
    --checkpoint_path checkpoints/wav2lip_gan.pth \
    --face "/content/LivePortrait/assets/examples/source/lizard.png" \
    --audio "/content/LivePortrait/assets/examples/driving/script.mp3" \
    --outfile "/content/lizard_final_test.mp4" \
    --static True \
    --box 100 450 100 450 \
    --pads 0 20 0 0
# Out:
# GPU available: True
# Device Name: Tesla T4
# /content/Wav2Lip
# Using cuda for inference.
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Models loaded
# Number of frames available for inference: 1
# Extracting raw audio...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x5a09597e1480] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/content/LivePortrait/assets/examples/driving/script.mp3':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Duration: 00:01:04.60, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'temp/temp.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    5564kB time=00:01:04.57 bitrate= 705.9kbits/s speed= 540x
# video:0kB audio:5564kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001369%
# (80, 5169)
# Length of mel chunks: 1612
#   0% 0/13 [00:00<?, ?it/s]Using the specified bounding box instead of face detection...
# 100% 13/13 [00:12<00:00,  1.01it/s]
# wav2lip prediction time: 12.874139785766602
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from 'temp/result.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:01:04.48, start: 0.000000, bitrate: 1708 kb/s
#   Stream #0:0: Video: mpeg4 (Simple Profile) (DIVX / 0x58564944), yuv420p, 682x1024 [SAR 1:1 DAR 341:512], 1704 kb/s, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from 'temp/temp.wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:01:04.60, bitrate: 705 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5a1e1f331400] using SAR=1/1
# [libx264 @ 0x5a1e1f331400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5a1e1f331400] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5a1e1f331400] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/lizard_final_test.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 682x1024 [SAR 1:1 DAR 341:512], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame= 1612 fps= 57 q=-1.0 Lsize=    2393kB time=00:01:04.59 bitrate= 303.5kbits/s speed=2.27x
# video:1792kB audio:548kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.277412%
# [libx264 @ 0x5a1e1f331400] frame I:7     Avg QP:15.54  size: 94853
# [libx264 @ 0x5a1e1f331400] frame P:605   Avg QP:18.49  size:  1331
# [libx264 @ 0x5a1e1f331400] frame B:1000  Avg QP:26.24  size:   365
# [libx264 @ 0x5a1e1f331400] consecutive B-frames: 13.8%  8.6%  5.4% 72.2%
# [libx264 @ 0x5a1e1f331400] mb I  I16..4:  8.9% 84.1%  7.0%
# [libx264 @ 0x5a1e1f331400] mb P  I16..4:  0.1%  0.7%  0.0%  P16..4:  6.0%  1.8%  0.9%  0.0%  0.0%    skip:90.5%
# [libx264 @ 0x5a1e1f331400] mb B  I16..4:  0.0%  0.2%  0.0%  B16..8:  4.7%  0.3%  0.0%  direct: 0.1%  skip:94.5%  L0:51.7% L1:45.5% BI: 2.9%
# [libx264 @ 0x5a1e1f331400] 8x8 transform intra:84.4% inter:92.0%
# [libx264 @ 0x5a1e1f331400] coded y,uvDC,uvAC intra: 69.8% 58.8% 14.7% inter: 1.5% 1.2% 0.0%
# [libx264 @ 0x5a1e1f331400] i16 v,h,dc,p: 40% 16% 17% 27%
# [libx264 @ 0x5a1e1f331400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 18% 31%  3%  3%  4%  4%  5%  5%
# [libx264 @ 0x5a1e1f331400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 20% 11%  5%  6%  6%  4%  6%  4%
# [libx264 @ 0x5a1e1f331400] i8c dc,h,v,p: 46% 25% 25%  5%
# [libx264 @ 0x5a1e1f331400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5a1e1f331400] ref P L0: 60.4% 12.0% 17.5% 10.1%
# [libx264 @ 0x5a1e1f331400] ref B L0: 79.5% 13.7%  6.8%
# [libx264 @ 0x5a1e1f331400] ref B L1: 96.1%  3.9%
# [libx264 @ 0x5a1e1f331400] kb/s:227.61
# [aac @ 0x5a1e1f333080] Qavg: 137.185

# %%
import torch
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
# %cd /content/Wav2Lip
# !python inference.py \
    --checkpoint_path checkpoints/wav2lip_gan.pth \
    --face "/content/LivePortrait/assets/examples/source/lizard.png" \
    --audio "/content/LivePortrait/assets/examples/driving/script.mp3" \
    --outfile "/content/lizard_final_test.mp4" \
    --static True \
    --box 100 450 100 450 \
    --pads 0 20 0 0
# Out:
# GPU available: True
# Device Name: Tesla T4
# /content/Wav2Lip
# Using cuda for inference.
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Models loaded
# Number of frames available for inference: 1
# Extracting raw audio...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x58d6178c3480] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/content/LivePortrait/assets/examples/driving/script.mp3':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Duration: 00:01:04.60, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 128 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'temp/temp.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    5564kB time=00:01:04.57 bitrate= 705.9kbits/s speed= 520x
# video:0kB audio:5564kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001369%
# (80, 5169)
# Length of mel chunks: 1612
#   0% 0/13 [00:00<?, ?it/s]Using the specified bounding box instead of face detection...
# 100% 13/13 [00:12<00:00,  1.01it/s]
# wav2lip prediction time: 12.872093915939331
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from 'temp/result.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:01:04.48, start: 0.000000, bitrate: 1708 kb/s
#   Stream #0:0: Video: mpeg4 (Simple Profile) (DIVX / 0x58564944), yuv420p, 682x1024 [SAR 1:1 DAR 341:512], 1704 kb/s, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from 'temp/temp.wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:01:04.60, bitrate: 705 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5697ff127400] using SAR=1/1
# [libx264 @ 0x5697ff127400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5697ff127400] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5697ff127400] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/lizard_final_test.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 682x1024 [SAR 1:1 DAR 341:512], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame= 1612 fps= 57 q=-1.0 Lsize=    2394kB time=00:01:04.59 bitrate= 303.7kbits/s speed=2.29x
# video:1793kB audio:548kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.275099%
# [libx264 @ 0x5697ff127400] frame I:7     Avg QP:15.53  size: 94906
# [libx264 @ 0x5697ff127400] frame P:611   Avg QP:18.76  size:  1321
# [libx264 @ 0x5697ff127400] frame B:994   Avg QP:26.30  size:   366
# [libx264 @ 0x5697ff127400] consecutive B-frames: 14.5%  8.2%  5.4% 72.0%
# [libx264 @ 0x5697ff127400] mb I  I16..4:  9.0% 84.0%  7.0%
# [libx264 @ 0x5697ff127400] mb P  I16..4:  0.1%  0.7%  0.0%  P16..4:  5.9%  1.8%  0.9%  0.0%  0.0%    skip:90.6%
# [libx264 @ 0x5697ff127400] mb B  I16..4:  0.0%  0.2%  0.0%  B16..8:  4.8%  0.3%  0.0%  direct: 0.1%  skip:94.5%  L0:51.4% L1:45.8% BI: 2.9%
# [libx264 @ 0x5697ff127400] 8x8 transform intra:84.5% inter:91.9%
# [libx264 @ 0x5697ff127400] coded y,uvDC,uvAC intra: 70.0% 58.8% 14.6% inter: 1.5% 1.2% 0.0%
# [libx264 @ 0x5697ff127400] i16 v,h,dc,p: 40% 16% 17% 27%
# [libx264 @ 0x5697ff127400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 18% 31%  3%  3%  4%  4%  5%  5%
# [libx264 @ 0x5697ff127400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 20% 11%  4%  6%  6%  4%  6%  4%
# [libx264 @ 0x5697ff127400] i8c dc,h,v,p: 45% 25% 25%  5%
# [libx264 @ 0x5697ff127400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5697ff127400] ref P L0: 60.1% 12.1% 17.5% 10.3%
# [libx264 @ 0x5697ff127400] ref B L0: 79.9% 13.4%  6.7%
# [libx264 @ 0x5697ff127400] ref B L1: 95.9%  4.1%
# [libx264 @ 0x5697ff127400] kb/s:227.74
# [aac @ 0x5697ff129080] Qavg: 137.185
